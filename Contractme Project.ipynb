# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
survey = pd.read_csv('_A Service Product Survey 1.csv')
survey
# Out:
#       ID        Start time   Completion time      Email  Name  \
# 0      1   2/9/23 19:47:26   2/9/23 19:49:15  anonymous   NaN
# 1      2  2/11/23 22:30:59  2/11/23 22:34:11  anonymous   NaN
# 2      3  2/11/23 22:35:24  2/11/23 22:36:38  anonymous   NaN
# 3      4   2/12/23 2:11:37   2/12/23 2:13:24  anonymous   NaN
# 4      5   2/12/23 7:38:20   2/12/23 7:43:49  anonymous   NaN
# ..   ...               ...               ...        ...   ...
# 112  113  2/14/23 20:54:58  2/14/23 20:57:15  anonymous   NaN
# 113  114   2/15/23 4:07:41   2/15/23 4:08:52  anonymous   NaN
# 114  115   2/15/23 8:30:47   2/15/23 8:37:36  anonymous   NaN
# 115  116   2/15/23 8:49:39   2/15/23 9:01:58  anonymous   NaN
# 116  117   2/15/23 9:50:40   2/15/23 9:51:51  anonymous   NaN
#
#     Personal Information:\nGender: Location ( e.g Lagos state)      Age:  \
# 0                            Woman                   Nasarawa      25-34
# ...

# %% [markdown]
# Data Properties and Cleaning

# %%
#Checking for null values
survey.isnull().sum()
# Out:
# ID                                                                                                                                             0
# Start time                                                                                                                                     0
# Completion time                                                                                                                                0
# Email                                                                                                                                          0
# Name                                                                                                                                         117
# Personal Information:\nGender:                                                                                                                 0
# ...

# %%
#Checking for information 
survey.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 117 entries, 0 to 116
# Data columns (total 21 columns):
#  #   Column                                                                                                                                    Non-Null Count  Dtype
# ---  ------                                                                                                                                    --------------  -----
#  0   ID                                                                                                                                        117 non-null    int64
#  1   Start time                                                                                                                                117 non-null    object
#  2   Completion time                                                                                                                           117 non-null    object
# ...

# %%
#Checking for the top 5 data
survey.head(5)
# Out:
#    ID        Start time   Completion time      Email  Name  \
# 0   1   2/9/23 19:47:26   2/9/23 19:49:15  anonymous   NaN
# 1   2  2/11/23 22:30:59  2/11/23 22:34:11  anonymous   NaN
# 2   3  2/11/23 22:35:24  2/11/23 22:36:38  anonymous   NaN
# 3   4   2/12/23 2:11:37   2/12/23 2:13:24  anonymous   NaN
# 4   5   2/12/23 7:38:20   2/12/23 7:43:49  anonymous   NaN
#
#   Personal Information:\nGender: Location ( e.g Lagos state)   Age:  \
# 0                          Woman                   Nasarawa   25-34
# 1                          Woman                Rivers state  25-34
# 2                          Woman                       Lagos  25-34
# 3                          Woman               Port harcourt  25-34
# 4                          Woman                       Enugu  25-34
#
#          Occupation  What is the nature of your Job?  ...  \
# 0    Business owner                              NaN  ...
# 1    Business owner                              NaN  ...
# ...

# %%
# Checking for the bottom 5 data
survey.tail(5)
# Out:
#       ID        Start time   Completion time      Email  Name  \
# 112  113  2/14/23 20:54:58  2/14/23 20:57:15  anonymous   NaN
# 113  114   2/15/23 4:07:41   2/15/23 4:08:52  anonymous   NaN
# 114  115   2/15/23 8:30:47   2/15/23 8:37:36  anonymous   NaN
# 115  116   2/15/23 8:49:39   2/15/23 9:01:58  anonymous   NaN
# 116  117   2/15/23 9:50:40   2/15/23 9:51:51  anonymous   NaN
#
#     Personal Information:\nGender: Location ( e.g Lagos state)      Age:  \
# 112                          Woman                   Oyo state     18-24
# 113                          Woman                     Bauchi      25-34
# 114                          Woman                Rivers State     25-34
# 115                            Man                 Lagos state  Above 60
# 116                          Woman               Portharcourt      25-34
#
#            Occupation  What is the nature of your Job?  ...  \
# 112           Student                              NaN  ...
# ...

# %%
# Shape of the data
survey.shape
# Out:
# (117, 21)

# %%
survey.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 112    False
# 113    False
# 114    False
# 115    False
# 116    False
# Length: 117, dtype: bool

# %%
survey.nunique()
# Out:
# ID                                                                                                                                           117
# Start time                                                                                                                                   117
# Completion time                                                                                                                              117
# Email                                                                                                                                          1
# Name                                                                                                                                           0
# Personal Information:\nGender:                                                                                                                 4
# ...

# %%
#Describing the data set
survey.describe()
# Out:
#                ID  Name
# count  117.000000   0.0
# mean    59.000000   NaN
# std     33.919021   NaN
# min      1.000000   NaN
# 25%     30.000000   NaN
# 50%     59.000000   NaN
# 75%     88.000000   NaN
# max    117.000000   NaN

# %%
#Renaming the columns
survey.columns = ["ID", "Start_Time", "Completion_Time", "Email", "Name", "Gender", "Location", "Age", "Occupation", "Nature_Job", "...", "Service_Type",  "Interested_SME_Product", "Preferred_Job_Location", "Information_know_SME", "Ever_used _service_product_website", "Experience_product", "Interest_service_product", "Frequency_use", "Demanded_Service", "Feedback"]
survey
# Out:
#       ID        Start_Time   Completion_Time      Email  Name Gender  \
# 0      1   2/9/23 19:47:26   2/9/23 19:49:15  anonymous   NaN  Woman
# 1      2  2/11/23 22:30:59  2/11/23 22:34:11  anonymous   NaN  Woman
# 2      3  2/11/23 22:35:24  2/11/23 22:36:38  anonymous   NaN  Woman
# 3      4   2/12/23 2:11:37   2/12/23 2:13:24  anonymous   NaN  Woman
# 4      5   2/12/23 7:38:20   2/12/23 7:43:49  anonymous   NaN  Woman
# ..   ...               ...               ...        ...   ...    ...
# 112  113  2/14/23 20:54:58  2/14/23 20:57:15  anonymous   NaN  Woman
# 113  114   2/15/23 4:07:41   2/15/23 4:08:52  anonymous   NaN  Woman
# 114  115   2/15/23 8:30:47   2/15/23 8:37:36  anonymous   NaN  Woman
# 115  116   2/15/23 8:49:39   2/15/23 9:01:58  anonymous   NaN    Man
# 116  117   2/15/23 9:50:40   2/15/23 9:51:51  anonymous   NaN  Woman
#
#           Location       Age        Occupation                 Nature_Job  \
# ...

# %%
# Filling the null values with "not specified"
survey = survey.fillna({"Name": "not specified", "Nature_Job": "not specified",  "Service_Type": "not specified", "Interested_SME_Product": "not specified","Preferred_Job_Location": "not specified", "Experience_product": "not specified", "Information_know_SME": "not specified", "Feedback": "not specified"})
survey
# Out:
#       ID        Start_Time   Completion_Time      Email           Name Gender  \
# 0      1   2/9/23 19:47:26   2/9/23 19:49:15  anonymous  not specified  Woman
# 1      2  2/11/23 22:30:59  2/11/23 22:34:11  anonymous  not specified  Woman
# 2      3  2/11/23 22:35:24  2/11/23 22:36:38  anonymous  not specified  Woman
# 3      4   2/12/23 2:11:37   2/12/23 2:13:24  anonymous  not specified  Woman
# 4      5   2/12/23 7:38:20   2/12/23 7:43:49  anonymous  not specified  Woman
# ..   ...               ...               ...        ...            ...    ...
# 112  113  2/14/23 20:54:58  2/14/23 20:57:15  anonymous  not specified  Woman
# 113  114   2/15/23 4:07:41   2/15/23 4:08:52  anonymous  not specified  Woman
# 114  115   2/15/23 8:30:47   2/15/23 8:37:36  anonymous  not specified  Woman
# 115  116   2/15/23 8:49:39   2/15/23 9:01:58  anonymous  not specified    Man
# 116  117   2/15/23 9:50:40   2/15/23 9:51:51  anonymous  not specified  Woman
#
# ...

# %%
# Checking if the null values have been replaced
survey.isnull().sum()
# Out:
# ID                                     0
# Start_Time                             0
# Completion_Time                        0
# Email                                  0
# Name                                   0
# Gender                                 0
# Location                               0
# Age                                    0
# Occupation                             0
# Nature_Job                             0
# ...                                   86
# Service_Type                           0
# Interested_SME_Product                 0
# Preferred_Job_Location                 0
# Information_know_SME                   0
# Ever_used _service_product_website     0
# Experience_product                     0
# Interest_service_product               0
# Frequency_use                          0
# Demanded_Service                       0
# Feedback                               0
# dtype: int64

# %%
#Checking for the data types of the columns 
survey.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 117 entries, 0 to 116
# Data columns (total 21 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   ID                                  117 non-null    int64
#  1   Start_Time                          117 non-null    object
#  2   Completion_Time                     117 non-null    object
#  3   Email                               117 non-null    object
#  4   Name                                117 non-null    object
#  5   Gender                              117 non-null    object
#  6   Location                            117 non-null    object
#  7   Age                                 117 non-null    object
#  8   Occupation                          117 non-null    object
#  9   Nature_Job                          117 non-null    object
#  10  ...                                 31 non-null     object
# ...

# %%
# Converting the date columns to pandas datatime
survey["Start_Time"] = pd.to_datetime(survey.Start_Time)
survey["Completion_Time"] = pd.to_datetime(survey.Completion_Time)
survey
# Out:
#       ID          Start_Time     Completion_Time      Email           Name  \
# 0      1 2023-02-09 19:47:26 2023-02-09 19:49:15  anonymous  not specified
# 1      2 2023-02-11 22:30:59 2023-02-11 22:34:11  anonymous  not specified
# 2      3 2023-02-11 22:35:24 2023-02-11 22:36:38  anonymous  not specified
# 3      4 2023-02-12 02:11:37 2023-02-12 02:13:24  anonymous  not specified
# 4      5 2023-02-12 07:38:20 2023-02-12 07:43:49  anonymous  not specified
# ..   ...                 ...                 ...        ...            ...
# 112  113 2023-02-14 20:54:58 2023-02-14 20:57:15  anonymous  not specified
# 113  114 2023-02-15 04:07:41 2023-02-15 04:08:52  anonymous  not specified
# 114  115 2023-02-15 08:30:47 2023-02-15 08:37:36  anonymous  not specified
# 115  116 2023-02-15 08:49:39 2023-02-15 09:01:58  anonymous  not specified
# 116  117 2023-02-15 09:50:40 2023-02-15 09:51:51  anonymous  not specified
#
#     Gender       Location       Age        Occupation  \
# ...

# %%
survey.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 117 entries, 0 to 116
# Data columns (total 21 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   ID                                  117 non-null    int64
#  1   Start_Time                          117 non-null    datetime64[ns]
#  2   Completion_Time                     117 non-null    datetime64[ns]
#  3   Email                               117 non-null    object
#  4   Name                                117 non-null    object
#  5   Gender                              117 non-null    object
#  6   Location                            117 non-null    object
#  7   Age                                 117 non-null    object
#  8   Occupation                          117 non-null    object
#  9   Nature_Job                          117 non-null    object
#  10  ...                                 31 non-null     object
# ...

# %%
#Check the value count for type column
survey["Gender"].value_counts()
# Out:
# Woman                89
# Man                  26
# Non-binary            1
# Prefer not to say     1
# Name: Gender, dtype: int64

# %%
#Check the value count for type column
survey["Age"].value_counts()
# Out:
# 25-34       83
# 18-24       25
# 35-44        8
# Above 60     1
# Name: Age, dtype: int64

# %%
survey["Interest_service_product"].value_counts()
# Out:
# Yes          93
# Undecided    20
# No            4
# Name: Interest_service_product, dtype: int64

# %% [markdown]
# ### Machine Learning and Modeling

# %%
survey
# Out:
#       ID          Start_Time     Completion_Time      Email           Name  \
# 0      1 2023-02-09 19:47:26 2023-02-09 19:49:15  anonymous  not specified
# 1      2 2023-02-11 22:30:59 2023-02-11 22:34:11  anonymous  not specified
# 2      3 2023-02-11 22:35:24 2023-02-11 22:36:38  anonymous  not specified
# 3      4 2023-02-12 02:11:37 2023-02-12 02:13:24  anonymous  not specified
# 4      5 2023-02-12 07:38:20 2023-02-12 07:43:49  anonymous  not specified
# ..   ...                 ...                 ...        ...            ...
# 112  113 2023-02-14 20:54:58 2023-02-14 20:57:15  anonymous  not specified
# 113  114 2023-02-15 04:07:41 2023-02-15 04:08:52  anonymous  not specified
# 114  115 2023-02-15 08:30:47 2023-02-15 08:37:36  anonymous  not specified
# 115  116 2023-02-15 08:49:39 2023-02-15 09:01:58  anonymous  not specified
# 116  117 2023-02-15 09:50:40 2023-02-15 09:51:51  anonymous  not specified
#
#     Gender       Location       Age        Occupation  \
# ...

# %% [markdown]
# ### 4 columns was choosen for ML (Gender, Interest_service_product,Frequency_use, Age), where Interest_service_product = dependent variables and the rest independent variable.

# %%
#Creating a dataframe for the independent and dependent data set
sub_survey = sub_survey[["Gender", "Interest_service_product", "Frequency_use","Age"]]
sub_survey
# Out:
#      Gender  Interest_service_product  Frequency_use  Age
# 0         3                         2              0    1
# 1         3                         2              0    1
# 2         3                         2              0    1
# 3         3                         2              0    1
# 4         3                         2              5    1
# ..      ...                       ...            ...  ...
# 112       3                         2              5    0
# 113       3                         1              3    1
# 114       3                         2              5    1
# 115       0                         1              3    3
# 116       3                         2              5    1
#
# [117 rows x 4 columns]

# %%
#Importing LableEncoder
from sklearn.preprocessing import LabelEncoder

# %%
label_encoder = LabelEncoder()

# %%
label_encoder
# Out:
# LabelEncoder()

# %%
#Converting the columns from text data to numerical data
sub_survey["Interest_service_product"] = label_encoder.fit_transform(sub_survey["Interest_service_product"])
sub_survey ["Age"] = label_encoder.fit_transform(sub_survey["Age"])
sub_survey ["Frequency_use"] = label_encoder.fit_transform(sub_survey ["Frequency_use"])
sub_survey["Gender"] = label_encoder.fit_transform(sub_survey ["Gender"])
`

# %%
sub_survey
# Out:
#      Gender  Interest_service_product  Frequency_use  Age
# 0         3                         2              0    1
# 1         3                         2              0    1
# 2         3                         2              0    1
# 3         3                         2              0    1
# 4         3                         2              5    1
# ..      ...                       ...            ...  ...
# 112       3                         2              5    0
# 113       3                         1              3    1
# 114       3                         2              5    1
# 115       0                         1              3    3
# 116       3                         2              5    1
#
# [117 rows x 4 columns]

# %%
# Finding the unique values in Gender column from the new dataframe
sub_survey["Gender"].unique()
# Out:
# array([3, 0, 1, 2], dtype=int64)

# %%
# Finding the unique values for the gender column from the original dataframe
survey["Gender"].unique()
# Out:
# array(['Woman', 'Man', 'Non-binary', 'Prefer not to say'], dtype=object)

# %%
## Finding the unique values counts for the gender column from the new  dataframe
sub_survey["Gender"].value_counts()
# Out:
# 3    89
# 0    26
# 1     1
# 2     1
# Name: Gender, dtype: int64

# %%
sub_survey["Interest_service_product"].value_counts()
# Out:
# 2    93
# 1    20
# 0     4
# Name: Interest_service_product, dtype: int64

# %%
# Droping the dependent variable and asigning x to the independent variables
x = sub_survey.drop(['Interest_service_product'], axis = 'columns')
x
# Out:
#      Gender  Frequency_use  Age
# 0         3              0    1
# 1         3              0    1
# 2         3              0    1
# 3         3              0    1
# 4         3              5    1
# ..      ...            ...  ...
# 112       3              5    0
# 113       3              3    1
# 114       3              5    1
# 115       0              3    3
# 116       3              5    1
#
# [117 rows x 3 columns]

# %%
# Assigning the dependent variable to y
y = sub_survey['Interest_service_product']
y
# Out:
# 0      2
# 1      2
# 2      2
# 3      2
# 4      2
#       ..
# 112    2
# 113    1
# 114    2
# 115    1
# 116    2
# Name: Interest_service_product, Length: 117, dtype: int64

# %%
#import the train_test_split module to train 30% of the dataset 
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(x,y,train_size=0.3)

# %% [markdown]
# ### Model 1: Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression
model = LogisticRegression()

# %%
model.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %%
y_pre = model.predict(X_test)
y_pre
# Out:
# array([2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2,
#        2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2,
#        2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2,
#        2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2], dtype=int64)

# %%
model.score(X_test,y_test)
# Out:
# 0.7682926829268293

# %% [markdown]
# ### Confusion Matrix

# %%
from sklearn.metrics import confusion_matrix

cm = confusion_matrix(y_test, y_pre)

sns.heatmap(cm, annot = True)
plt.xlabel('Predicted ')
plt.ylabel('Actual ')
# Out:
# Text(33.0, 0.5, 'Actual ')

# %% [markdown]
# ### Model 2: Decision Tree

# %%
from sklearn import tree
tree.DecisionTreeClassifier()
Model = tree.DecisionTreeClassifier()

# %%
Model.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
y_pred = Model.predict(X_test)

# %%
Model.score(X_test, y_test)
# Out:
# 0.6951219512195121

# %% [markdown]
# ### Classification Report

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test,y_pre))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         1
#            1       0.00      0.00      0.00        18
#            2       0.77      1.00      0.87        63
#
#     accuracy                           0.77        82
#    macro avg       0.26      0.33      0.29        82
# weighted avg       0.59      0.77      0.67        82
# C:\Users\pc\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\pc\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
# ...

# %% [markdown]
# ### Confusion Matrix

# %%
from sklearn.metrics import confusion_matrix

cm = confusion_matrix(y_test, y_pred)

sns.heatmap(cm, annot = True)
plt.xlabel('Predicted ')
plt.ylabel('Actual ')
# Out:
# Text(33.0, 0.5, 'Actual ')

# %% [markdown]
# ### Classification Report

# %%
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         1
#            1       0.40      0.22      0.29        18
#            2       0.85      0.84      0.85        63
#
#     accuracy                           0.70        82
#    macro avg       0.42      0.35      0.38        82
# weighted avg       0.74      0.70      0.71        82

# %% [markdown]
# ### Model 3: Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
model = RandomForestClassifier()

# %%
model.fit(X_train, y_train)
# Out:
# RandomForestClassifier()

# %%
y_predict = model.predict(X_test)

# %%
y_predict
# Out:
# array([2, 1, 2, 2, 2, 2, 2, 2, 2, 2, 0, 1, 2, 1, 2, 2, 2, 2, 0, 0, 2, 2,
#        2, 2, 2, 2, 0, 2, 1, 1, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 0, 2, 0, 2,
#        2, 2, 1, 2, 2, 2, 2, 2, 2, 0, 2, 2, 2, 2, 0, 2, 2, 1, 2, 1, 2, 2,
#        2, 2, 2, 2, 0, 2, 2, 1, 2, 2, 2, 2, 2, 2, 2, 1], dtype=int64)

# %%
model.score(X_test, y_test)
# Out:
# 0.6951219512195121

# %% [markdown]
# ### Confusion Matrix

# %%
from sklearn.metrics import confusion_matrix

cm = confusion_matrix(y_test, y_predict)

sns.heatmap(cm, annot = True)
plt.xlabel('Predicted ')
plt.ylabel('Actual ')
# Out:
# Text(33.0, 0.5, 'Actual ')

# %% [markdown]
# ### Classification Report

# %%
Report=classification_report
print(classification_report(y_test,y_predict))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         1
#            1       0.40      0.22      0.29        18
#            2       0.84      0.84      0.84        63
#
#     accuracy                           0.70        82
#    macro avg       0.41      0.35      0.38        82
# weighted avg       0.73      0.70      0.71        82
